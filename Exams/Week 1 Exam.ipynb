# %%
# Week 1 Exam
# You have 1 hour to complete this notebook.
# Email me your finalized notebook/python file.
# The exam is open book.
# Save the dataset as a text file and upload it to your google drive

# %%
# Questions
# 1) How many records are in the dataset?
# 2) What year is the oldest song in the dataset from?
# 3) What is the most popular song in the dataset?
# 4) How many unique genres are there?
# 5) What is the most popular genre?
# 6) What is the most popular artist by total number of songs on the list?
# 7) Who is the artist of the longest song name?
# 8) What is the total duration of songs in ms?
# 9) What is the most popular song from 2003?
# 10) Save the original DataFrame as a parquet file using the default settings. How large is the file rounded to the nearest Kb?'
